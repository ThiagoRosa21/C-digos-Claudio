# %%
from google.colab import files # subir arquivo
import cv2 # biblioteca openCV
from google.colab.patches import cv2_imshow # exibir imagem (só precisa pro colab)
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Carregamento da imagem

# %%
arquivo = files.upload()
# Out:
#      <input type="file" id="files-a6f1e897-9a24-4902-8919-c3e1de960fdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6f1e897-9a24-4902-8919-c3e1de960fdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Leitura e exibição do arquivo de imagem

# %%
img = cv2.imread('baguette.jpg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
img_mod = img/2
cv2_imshow(img_mod)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
img_mod_2 = img*2
cv2_imshow(img_mod_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
B, G, R = cv2.split(img)
cv2_imshow(B)

# passar só uma camada faz imprimir em grayscale
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>

# %%
plt.subplot(1,3,1)
plt.imshow(B, cmap='gray')
plt.axis('off') # tira as linhas e números do plot
plt.title('Azul (B)')

plt.subplot(1,3,2)
plt.imshow(G, cmap='gray')
plt.axis('off')
plt.title('Verde (G)')

plt.subplot(1,3,3)
plt.imshow(R, cmap='gray')
plt.axis('off')
plt.title('Vermelho (R)')
# Out:
# Text(0.5, 1.0, 'Vermelho (R)')

# %%
n = np.arange(0,20)

plt.subplot(2,2,1)
plt.plot(n,np.sin(n))

plt.subplot(2,2,2)
plt.plot(n,np.cos(n))

plt.subplot(2,2,3)
plt.plot(n)

plt.subplot(2,2,4)
plt.plot(n*n)
